# %%
import pandas as pd
from tqdm import tqdm
import ktest
from ktest.tester import Ktest

# %% [markdown]
# # Ktest: two-sample kernel tests for large datasets
# ## Univariate testing: example

# %% [markdown]
# Loading data:

# %%
data = pd.read_csv('v5_data/RTqPCR_reversion_logcentered.csv', index_col=0)
meta = pd.Series(data = pd.Series(data.index).apply(lambda x : x.split(sep='.')[1]))
meta.index = data.index

# %% [markdown]
# Performing ktest in the univariate setting on every gene:

# %%
univ_test_stats = pd.DataFrame()
univ_test_pvalues = pd.DataFrame()
it = tqdm(range(len(data.columns)))
for i in it:
    kt = Ktest(data=data.iloc[:, i], metadata=meta, sample_names=['48HREV','48HDIFF'])
    kt.test(verbose=0)
    univ_test_stats[data.columns[i]] = kt.kfda_statistic
    univ_test_pvalues[data.columns[i]] = kt.kfda_pval_asymp
#univ_test_stats.index + 1
#univ_test_pvalues.index + 1
# Out:
# 100%|███████████████████████████████████████████| 83/83 [00:04<00:00, 17.57it/s]

# %%
univ_test_stats
# Out:
#              AACS         ACSL6         ACSS1         ALAS1        AMDHD2  \
# 1    6.500657e+01  2.550526e+01  4.213474e-02  2.271508e+01  5.347271e+00
# 2    8.669478e+01  2.574460e+01  2.804698e-01  2.327220e+01  5.869098e+00
# 3    8.690018e+01  3.560538e+01  3.083135e-01  2.474821e+01  5.941839e+00
# 4    8.699158e+01  3.622324e+01  3.972957e+01  2.633151e+01  6.065752e+00
# 5    8.789414e+01  4.055196e+01  3.990516e+01  2.674954e+01  7.176830e+00
# ..            ...           ...           ...           ...           ...
# 335  3.354676e+07  1.074528e+08  3.003149e+07  1.285689e+08  1.053463e+07
# 336  3.354677e+07  1.074528e+08  3.003151e+07  1.285689e+08  1.053463e+07
# 337  3.354677e+07  1.074528e+08  3.003153e+07  1.285689e+08  1.053463e+07
# 338  3.354677e+07  1.074528e+08  3.003153e+07  1.285689e+08  1.053463e+07
# 339  3.354677e+07  1.074528e+08  3.003153e+07  1.285690e+08  1.053463e+07
#
#           ARHGEF2          BATF        BCL11A    betaglobin           BPI  \
# 1    2.953256e+01  2.167280e+01  6.187004e+00  1.761241e+02  3.268788e+02
# 2    9.111101e+01  3.135184e+01  1.364031e+01  4.526613e+02  3.741858e+02
# 3    9.123997e+01  3.331336e+01  1.364394e+01  4.721999e+02  3.879747e+02
# 4    9.306518e+01  3.472160e+01  1.476397e+01  4.894778e+02  3.889037e+02
# 5    9.309713e+01  3.656604e+01  1.683108e+01  4.914472e+02  3.942524e+02
# ..            ...           ...           ...           ...           ...
# 335  3.163633e+07  2.013671e+08  2.779589e+06  3.468310e+07  1.630697e+10
# 336  3.163634e+07  2.013671e+08  2.779590e+06  3.468321e+07  1.630697e+10
# 337  3.163635e+07  2.013671e+08  2.779591e+06  3.468321e+07  1.630697e+10
# 338  3.163637e+07  2.013671e+08  2.779591e+06  3.468331e+07  1.630697e+10
# 339  3.163637e+07  2.013671e+08  2.779592e+06  3.468331e+07  1.630697e+10
#
#      ...       SULT1E1        TADA2L        TBC1D7      TNFRSF21  \
# 1    ...  3.735462e+00  3.864591e+00  6.251075e+01  4.210406e+00
# 2    ...  6.586504e+00  4.433652e+00  1.107528e+02  4.417409e+00
# 3    ...  7.041369e+00  4.715040e+00  1.140466e+02  4.617113e+00
# 4    ...  7.527867e+00  4.954322e+00  1.158302e+02  8.975771e+00
# 5    ...  1.183042e+01  5.564658e+00  1.167429e+02  1.219723e+01
# ..   ...           ...           ...           ...           ...
# 335  ...  1.489452e+06  2.790904e+06  1.285453e+07  1.049110e+08
# 336  ...  1.489452e+06  2.790906e+06  1.285467e+07  1.049110e+08
# 337  ...  1.489452e+06  2.790908e+06  1.285467e+07  1.049111e+08
# 338  ...  1.489454e+06  2.790908e+06  1.285469e+07  1.049111e+08
# 339  ...  1.489454e+06  2.790908e+06  1.285469e+07  1.049111e+08
#
#              TPP1         TTYH2          UCK1          VDAC3         WDR91  \
# 1    1.206895e-01  2.869715e+01  4.304049e+01       1.039036  1.160775e+01
# 2    1.885443e-01  4.936064e+01  5.701519e+01       2.423536  1.162395e+01
# 3    3.607959e-01  5.252313e+01  7.081363e+01       2.592017  1.729174e+01
# 4    5.696544e+00  5.252419e+01  7.174169e+01       2.942043  1.767564e+01
# 5    7.909153e+00  5.355575e+01  8.355143e+01       3.418828  1.769228e+01
# ..            ...           ...           ...            ...           ...
# 335  2.300669e+07  1.447153e+07  4.001264e+06  977875.766045  1.760820e+06
# 336  2.300669e+07  1.447154e+07  4.001269e+06  977875.769699  1.760821e+06
# 337  2.300669e+07  1.447154e+07  4.001269e+06  977876.150054  1.760824e+06
# 338  2.300669e+07  1.447154e+07  4.001276e+06  977878.690761  1.760824e+06
# 339  2.300669e+07  1.447154e+07  4.001300e+06  977878.967384  1.760836e+06
#
#           XPNPEP1
# 1    7.167725e+00
# 2    7.464668e+00
# 3    7.465986e+00
# 4    7.701123e+00
# 5    7.701915e+00
# ..            ...
# 335  5.212110e+06
# 336  5.212111e+06
# 337  5.212112e+06
# 338  5.212112e+06
# 339  5.212118e+06
#
# [339 rows x 83 columns]

# %%
univ_test_pvalues
# Out:
#              AACS         ACSL6         ACSS1     ALAS1    AMDHD2  \
# 1    7.464872e-16  4.411796e-07  8.373631e-01  0.000002  0.020755
# 2    1.494402e-19  2.568208e-06  8.691540e-01  0.000009  0.053155
# 3    1.014449e-18  9.074194e-08  9.584574e-01  0.000017  0.114474
# 4    5.732410e-18  2.603278e-07  4.923200e-08  0.000027  0.194291
# 5    1.860058e-17  1.155598e-07  1.560598e-07  0.000064  0.207818
# ..            ...           ...           ...       ...       ...
# 335  0.000000e+00  0.000000e+00  0.000000e+00  0.000000  0.000000
# 336  0.000000e+00  0.000000e+00  0.000000e+00  0.000000  0.000000
# 337  0.000000e+00  0.000000e+00  0.000000e+00  0.000000  0.000000
# 338  0.000000e+00  0.000000e+00  0.000000e+00  0.000000  0.000000
# 339  0.000000e+00  0.000000e+00  0.000000e+00  0.000000  0.000000
#
#           ARHGEF2          BATF    BCL11A     betaglobin           BPI  ...  \
# 1    5.498525e-08  3.233445e-06  0.012869   3.402097e-40  4.598320e-73  ...
# 2    1.642467e-20  1.556085e-07  0.001092   5.079760e-99  5.579451e-82  ...
# 3    1.186341e-19  2.765926e-07  0.003432  5.046757e-102  8.908986e-84  ...
# 4    2.938626e-19  5.298969e-07  0.005217  1.263932e-104  6.945144e-83  ...
# 5    1.500917e-18  7.317171e-07  0.004832  5.601162e-104  5.139957e-83  ...
# ..            ...           ...       ...            ...           ...  ...
# 335  0.000000e+00  0.000000e+00  0.000000   0.000000e+00  0.000000e+00  ...
# 336  0.000000e+00  0.000000e+00  0.000000   0.000000e+00  0.000000e+00  ...
# 337  0.000000e+00  0.000000e+00  0.000000   0.000000e+00  0.000000e+00  ...
# 338  0.000000e+00  0.000000e+00  0.000000   0.000000e+00  0.000000e+00  ...
# 339  0.000000e+00  0.000000e+00  0.000000   0.000000e+00  0.000000e+00  ...
#
#       SULT1E1    TADA2L        TBC1D7  TNFRSF21      TPP1         TTYH2  \
# 1    0.053269  0.049315  2.649947e-15  0.040177  0.728288  8.462801e-08
# 2    0.037133  0.108954  8.919179e-25  0.109843  0.910035  1.911936e-11
# 3    0.070591  0.193893  1.476852e-24  0.202079  0.948217  2.316901e-11
# 4    0.110487  0.292017  4.149718e-24  0.061708  0.222986  1.071707e-10
# 5    0.037187  0.350908  1.535950e-23  0.032183  0.161314  2.586049e-10
# ..        ...       ...           ...       ...       ...           ...
# 335  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000e+00
# 336  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000e+00
# 337  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000e+00
# 338  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000e+00
# 339  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000e+00
#
#              UCK1     VDAC3     WDR91   XPNPEP1
# 1    5.361874e-11  0.308046  0.000657  0.007423
# 2    4.162067e-13  0.297671  0.002992  0.023937
# 3    2.857733e-15  0.458891  0.000616  0.058439
# 4    9.731340e-15  0.567571  0.001428  0.103161
# 5    1.514560e-16  0.635704  0.003358  0.173447
# ..            ...       ...       ...       ...
# 335  0.000000e+00  0.000000  0.000000  0.000000
# 336  0.000000e+00  0.000000  0.000000  0.000000
# 337  0.000000e+00  0.000000  0.000000  0.000000
# 338  0.000000e+00  0.000000  0.000000  0.000000
# 339  0.000000e+00  0.000000  0.000000  0.000000
#
# [339 rows x 83 columns]

# %% [markdown]
# Calculate the Benjamini-Hochberg adjusted p-value:

# %%
def correct_BenjaminiHochberg_pval_of_dfcolumn(df):
    df = pd.concat([df,df.rank()],keys=['pval','rank'],axis=1)
    df['pvalc'] = df.apply(lambda x: len(df) * x['pval']/x['rank'],axis=1) # correction
    df['rankc'] = df['pvalc'].rank() # new order calculation
    corrected_pvals = []
    # Correction of p-values that changed order:
    l = []
    if not df['rankc'].equals(df['rank']):
        first_rank = df['rank'].sort_values().values[0]
        pvalc_prec = df.loc[df['rank']==first_rank,'pvalc'].iat[0]
        df['rank'] = df['rank'].fillna(10000)
        for rank in df['rank'].sort_values().values[1:]:
            pvalc = df.loc[df['rank']==rank,'pvalc'].iat[0]
            if pvalc_prec >= 1 : 
                pvalue = 1 # l += [1]
            elif pvalc_prec > pvalc :
                pvalue = pvalc
            elif pvalc_prec <= pvalc:
                pvalue = pvalc_prec
            else: 
                print('error pval correction',f'rank{rank} pvalc{pvalc} pvalcprec{pvalc_prec}')
                print(df.loc[df['rank']==rank].index)
            pvalc_prec = pvalc
            l += [pvalue] 
        pvalue = 1 if pvalc >1 else pvalc
        l += [pvalue]
    if len(l)>0: 
        return(pd.Series(l,index=df['rank'].sort_values().index))
    else: 
        return(pd.Series(df['pvalc'].values,index=df['rank'].sort_values().index))

# %%
t = 10
t_pvalues_corrected = correct_BenjaminiHochberg_pval_of_dfcolumn(univ_test_pvalues.loc[t])
print("Top 5 DE genes (with BH correction): \n")
for g in t_pvalues_corrected.index[:5]:
    print(g)
# Out:
# Top 5 DE genes (with BH correction):
#
# betaglobin
# BPI
# FHL3
# LDHA
# CRIP2
